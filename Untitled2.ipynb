# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('exam.csv')

# %%
df.head()
# Out:
#    hours_study  attendance  score
# 0            6          87  19.53
# 1            5          99  21.13
# 2            4          51  10.73
# 3            5          62  13.73
# 4            3          67  13.13

# %%
df.hours_study.describe()
# Out:
# count    2000.000000
# mean        3.535500
# std         1.709152
# min         1.000000
# 25%         2.000000
# 50%         4.000000
# 75%         5.000000
# max         6.000000
# Name: hours_study, dtype: float64

# %%
df.hours_study.plot(kind='box')
plt.title('A boxplot describing students hours of study')
plt.ylabel('Hours_study')

plt.show()

# %%
df.attendance.plot(kind='hist',bins=50)
# Out:
# <Axes: ylabel='Frequency'>
